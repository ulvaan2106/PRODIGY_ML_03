# %% [markdown]
# <a href="https://colab.research.google.com/github/streakcraze/PRODIGY_ML_03/blob/main/comparison_with_1Dneuralnet_(without_pca).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Data Acquisition

# %%
import shutil

shutil.unpack_archive("/content/drive/MyDrive/Colab Notebooks/image-classification-using-svm/dogs-vs-cats/train.zip")

# %%
import os

train_images_list = sorted(os.listdir("train"))

print(f"the train dataset has {len(train_images_list)} images")
# Out:
# the train dataset has 25000 images

# %%
print(train_images_list[0])
print(train_images_list[-1])
# Out:
# cat.0.jpg
# dog.9999.jpg

# %%
import re

cat_images = [x for x in train_images_list if re.match("cat", x)]
dog_images = [x for x in train_images_list if re.match("dog", x)]

print(f"{len(cat_images)} cat images")
print(f"{len(dog_images)} dog images")
# Out:
# 12500 cat images
# 12500 dog images

# %% [markdown]
# # 2. Data Preprocessing

# %%
import numpy as np
from skimage import io, color, transform
import matplotlib.pyplot as plt
import gc

# %%
cat_img = io.imread(os.path.join("train", cat_images[1]))
cat_gray = color.rgb2gray(cat_img)

# plotting the original and grayscale images side by side
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cat_img, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cat_gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.show()

# %%
dog_img = io.imread(os.path.join("train", dog_images[10000]))
dog_gray = color.rgb2gray(dog_img)

# plotting the original and grayscale images side by side
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(dog_img, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(dog_gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.show()

# %%
features = np.array([])
# "0" for cat and "1" for dog
labels = np.append(np.full(12500, 0), np.full(12500, 1))

# %%
cat_features = []

print("loading cat images ...")

for img in cat_images:
  # load the RGB image
  rgb_img = io.imread(os.path.join("train", img))
  # convert RGB to grayscale
  gray_img = color.rgb2gray(rgb_img)
  # resize the image
  resized_img = transform.resize(gray_img, (50, 50))
  # normalize the image
  normalized_img = resized_img / 255.0
  # flatten the image array
  flat_img = normalized_img.flatten()
  # append to features list
  cat_features.append(flat_img)

features = np.vstack(cat_features)
del cat_features
gc.collect()
print("loaded cat images successfully")
# Out:
# loading cat images ...
# loaded cat images successfully

# %%
dog_features = []

print("loading dog images ...")

for img in dog_images:
  # load the RGB image
  rgb_img = io.imread(os.path.join("train", img))
  # convert RGB to grayscale
  gray_img = color.rgb2gray(rgb_img)
  # resize the image
  resized_img = transform.resize(gray_img, (50, 50))
  # normalize the image
  normalized_img = resized_img / 255.0
  # flatten the image array
  flat_img = normalized_img.flatten()
  # append to features list
  dog_features.append(flat_img)

features = np.append(features, dog_features, axis=0)
num_features = len(features[0])
del dog_features
gc.collect()
print("loaded dog images successfully")
# Out:
# loading dog images ...
# loaded dog images successfully

# %% [markdown]
# # 3. Model Training

# %%
from sklearn.model_selection import train_test_split

# %%
print("splitting data into training and test sets")
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=77, stratify=labels)
del features
del labels
gc.collect()
print("split completed")
# Out:
# splitting data into training and test sets
# split completed

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import joblib

# %%
model = Sequential()

# Input layer
model.add(Dense(128, input_shape=(num_features,), activation='relu'))

# Hidden layers
model.add(Dense(64, activation='relu'))

# Output layer with 1 neuron and sigmoid activation function for binary classification
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               320128
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 328449 (1.25 MB)
# Trainable params: 328449 (1.25 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print("model training started")
# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32)

joblib.dump(model, "/content/drive/MyDrive/Colab Notebooks/image-classification-using-svm/image_classifier_1Dneuralnet(2).sav")
del x_train
del y_train
gc.collect()
print("model artifact saved")
# Out:
# model training started
# Epoch 1/10
# 547/547 [==============================] - 5s 7ms/step - loss: 0.6915 - accuracy: 0.5230
# Epoch 2/10
# 547/547 [==============================] - 4s 7ms/step - loss: 0.6804 - accuracy: 0.5578
# Epoch 3/10
# 547/547 [==============================] - 5s 10ms/step - loss: 0.6708 - accuracy: 0.5873
# Epoch 4/10
# 547/547 [==============================] - 4s 7ms/step - loss: 0.6638 - accuracy: 0.6015
# Epoch 5/10
# 547/547 [==============================] - 4s 7ms/step - loss: 0.6587 - accuracy: 0.6038
# Epoch 6/10
# 547/547 [==============================] - 5s 9ms/step - loss: 0.6549 - accuracy: 0.6129
# Epoch 7/10
# 547/547 [==============================] - 4s 8ms/step - loss: 0.6520 - accuracy: 0.6169
# Epoch 8/10
# 547/547 [==============================] - 4s 7ms/step - loss: 0.6502 - accuracy: 0.6186
# Epoch 9/10
# 547/547 [==============================] - 4s 7ms/step - loss: 0.6479 - accuracy: 0.6231
# Epoch 10/10
# 547/547 [==============================] - 5s 10ms/step - loss: 0.6463 - accuracy: 0.6237
# model artifact saved

# %% [markdown]
# # 4. Model Evaluation

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# testing the model
y_pred = model.predict(x_test)
binary_y_pred = (y_pred > 0.5).astype(int)

# calculating the accuracy of the model
accuracy = accuracy_score(binary_y_pred, y_test)
print(f"The model is {accuracy*100}% accurate")
# Out:
# 235/235 [==============================] - 1s 3ms/step
# The model is 59.72% accurate

# %%
# printing the classification report
print("Classification report:")
print(classification_report(y_test, binary_y_pred, target_names=['cat', 'dog']))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#          cat       0.65      0.43      0.51      3750
#          dog       0.57      0.77      0.66      3750
#
#     accuracy                           0.60      7500
#    macro avg       0.61      0.60      0.59      7500
# weighted avg       0.61      0.60      0.59      7500

# %%
# plotting the confusion matrix
cm = confusion_matrix(y_test, binary_y_pred)
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[False, True])
cm_display.plot()
plt.show()

# %%
shutil.unpack_archive("/content/drive/MyDrive/Colab Notebooks/image-classification-using-svm/dogs-vs-cats/test1.zip")

# %%
test_images_list = sorted(os.listdir("test1"))

print(f"the test dataset has {len(test_images_list)} images")
# Out:
# the test dataset has 12500 images

# %%
test_img = io.imread(os.path.join("test1", test_images_list[80]))

plt.imshow(test_img)
plt.show()

gray_test_img = color.rgb2gray(test_img)
resized_test_img = transform.resize(gray_test_img, (50, 50))
normalized_test_img = resized_test_img / 255.0
flat_test_img = normalized_test_img.flatten()

img_pred = model.predict(np.array([flat_test_img]))

if(img_pred > 0.5):
    print("Model says it is a dog")
else:
    print("Model says it is a cat")
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Model says it is a dog

# %%
test_img = io.imread(os.path.join("test1", test_images_list[90]))

plt.imshow(test_img)
plt.show()

gray_test_img = color.rgb2gray(test_img)
resized_test_img = transform.resize(gray_test_img, (50, 50))
normalized_test_img = resized_test_img / 255.0
flat_test_img = normalized_test_img.flatten()

img_pred = model.predict(np.array([flat_test_img]))

if(img_pred > 0.5):
    print("Model says it is a dog")
else:
    print("Model says it is a cat")
# Out:
# 1/1 [==============================] - 0s 59ms/step
# Model says it is a cat
