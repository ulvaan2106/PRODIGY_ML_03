# %% [markdown]
# <a href="https://colab.research.google.com/github/streakcraze/PRODIGY_ML_03/blob/main/image_classification_using_svm_(with_sobel_edge_detection).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Data Acquisition

# %%
import shutil

shutil.unpack_archive("/content/drive/MyDrive/Colab Notebooks/image-classification-using-svm/dogs-vs-cats/train.zip")

# %%
import os

train_images_list = sorted(os.listdir("train"))

print(f"the train dataset has {len(train_images_list)} images")
# Out:
# the train dataset has 25000 images

# %%
print(train_images_list[0])
print(train_images_list[-1])
# Out:
# cat.0.jpg
# dog.9999.jpg

# %%
import re

cat_images = [x for x in train_images_list if re.match("cat", x)]
dog_images = [x for x in train_images_list if re.match("dog", x)]

print(f"{len(cat_images)} cat images")
print(f"{len(dog_images)} dog images")
# Out:
# 12500 cat images
# 12500 dog images

# %% [markdown]
# # 2. Data Preprocessing

# %%
import numpy as np
from skimage import io, color, filters, transform
import matplotlib.pyplot as plt
import gc

# %%
cat_img = io.imread(os.path.join("train", cat_images[1]))
cat_gray = color.rgb2gray(cat_img)

# applying Sobel edge detection
cat_edges = filters.sobel(cat_gray)

# plotting the original and edges images side by side
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cat_gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cat_edges, cmap='gray')
plt.title('Edges (Sobel)')
plt.axis('off')

plt.show()

# %%
dog_img = io.imread(os.path.join("train", dog_images[10000]))
dog_gray = color.rgb2gray(dog_img)

# applying Sobel edge detection
dog_edges = filters.sobel(dog_gray)

# plotting the original and edges images side by side
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(dog_gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(dog_edges, cmap='gray')
plt.title('Edges (Sobel)')
plt.axis('off')

plt.show()

# %%
features = np.array([])
# "0" for cat and "1" for dog
labels = np.append(np.full(12500, 0), np.full(12500, 1))

# %%
cat_features = []

print("loading cat images ...")

for img in cat_images:
  # load the RGB image
  rgb_img = io.imread(os.path.join("train", img))
  # convert RGB to grayscale
  gray_img = color.rgb2gray(rgb_img)
  # applying Sobel edge detection
  edge_img = filters.sobel(gray_img)
  # resize the image
  resized_img = transform.resize(edge_img, (50, 50))
  # normalize the image
  normalized_img = resized_img / 255.0
  # flatten the image array
  flat_img = normalized_img.flatten()
  # append to features list
  cat_features.append(flat_img)

features = np.vstack(cat_features)
del cat_features
gc.collect()
print("loaded cat images successfully")
# Out:
# loading cat images ...
# loaded cat images successfully

# %%
dog_features = []

print("loading dog images ...")

for img in dog_images:
  # load the RGB image
  rgb_img = io.imread(os.path.join("train", img))
  # convert RGB to grayscale
  gray_img = color.rgb2gray(rgb_img)
  # applying Sobel edge detection
  edge_img = filters.sobel(gray_img)
  # resize the image
  resized_img = transform.resize(edge_img, (50, 50))
  # normalize the image
  normalized_img = resized_img / 255.0
  # flatten the image array
  flat_img = normalized_img.flatten()
  # append to features list
  dog_features.append(flat_img)

features = np.append(features, dog_features, axis=0)
del dog_features
gc.collect()
print("loaded dog images successfully")
# Out:
# loading dog images ...
# loaded dog images successfully

# %%
from sklearn.decomposition import PCA

# %%
print("applying principal component analysis ...")
pca = PCA(n_components=0.9)
pca.fit(features)

principal_features = pca.transform(features)
print(f"features reduced from {len(features[0])} to {len(principal_features[0])}")

del features
gc.collect()
print("principal component analysis completed")
# Out:
# applying principal component analysis ...
# features reduced from 2500 to 566
# principal component analysis completed

# %% [markdown]
# # 3. Model Training

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import svm
import joblib

# %%
print("splitting data into training and test sets")
x_train, x_test, y_train, y_test = train_test_split(principal_features, labels, test_size=0.3, random_state=77, stratify=labels)
del principal_features
del labels
gc.collect()
print("split completed")
# Out:
# splitting data into training and test sets
# split completed

# %%
# Defining the parameters grid for GridSearchCV
param_grid = {'C': [0.1, 1, 10], 'gamma': [0.01, 0.1, "scale"]}

# Creating a support vector classifier
svc = svm.SVC(kernel="rbf", probability=True)

# Creating a model using GridSearchCV with the parameters grid
model = GridSearchCV(svc, param_grid, cv=2, verbose=3)

# %%
# training the model
print("model training started ...")
model.fit(x_train, y_train)
print("model training completed")

# cleaning up
joblib.dump(model, "/content/drive/MyDrive/Colab Notebooks/image-classification-using-svm/image_classifier_svm(5).sav")
del x_train
del y_train
gc.collect()
print("model artifact saved")
# Out:
# model training started ...
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [CV 1/2] END .................C=0.1, gamma=0.01;, score=0.516 total time= 4.0min
# [CV 2/2] END .................C=0.1, gamma=0.01;, score=0.515 total time= 4.1min
# [CV 1/2] END ..................C=0.1, gamma=0.1;, score=0.516 total time= 4.0min
# [CV 2/2] END ..................C=0.1, gamma=0.1;, score=0.515 total time= 4.1min
# [CV 1/2] END ................C=0.1, gamma=scale;, score=0.626 total time= 3.7min
# [CV 2/2] END ................C=0.1, gamma=scale;, score=0.620 total time= 3.7min
# [CV 1/2] END ...................C=1, gamma=0.01;, score=0.516 total time= 3.9min
# [CV 2/2] END ...................C=1, gamma=0.01;, score=0.515 total time= 4.1min
# [CV 1/2] END ....................C=1, gamma=0.1;, score=0.516 total time= 4.0min
# [CV 2/2] END ....................C=1, gamma=0.1;, score=0.515 total time= 4.5min
# [CV 1/2] END ..................C=1, gamma=scale;, score=0.648 total time= 3.8min
# [CV 2/2] END ..................C=1, gamma=scale;, score=0.644 total time= 3.7min
# [CV 1/2] END ..................C=10, gamma=0.01;, score=0.516 total time= 4.3min
# [CV 2/2] END ..................C=10, gamma=0.01;, score=0.515 total time= 4.5min
# [CV 1/2] END ...................C=10, gamma=0.1;, score=0.516 total time= 4.4min
# [CV 2/2] END ...................C=10, gamma=0.1;, score=0.515 total time= 4.5min
# [CV 1/2] END .................C=10, gamma=scale;, score=0.631 total time= 4.6min
# [CV 2/2] END .................C=10, gamma=scale;, score=0.636 total time= 4.7min
# model training completed
# model artifact saved

# %% [markdown]
# # 4. Model Evaluation

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# testing the model
y_pred = model.predict(x_test)

# calculating the accuracy of the model
accuracy = accuracy_score(y_pred, y_test)
print(f"The model is {accuracy*100}% accurate")
# Out:
# The model is 65.64% accurate

# %%
# printing the classification report
print("Classification report:")
print(classification_report(y_test, y_pred, target_names=['cat', 'dog']))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#          cat       0.64      0.71      0.67      3750
#          dog       0.68      0.60      0.64      3750
#
#     accuracy                           0.66      7500
#    macro avg       0.66      0.66      0.66      7500
# weighted avg       0.66      0.66      0.66      7500

# %%
# plotting the confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["cats", "dogs"])
cm_display.plot()
plt.show()

# %%
shutil.unpack_archive("/content/drive/MyDrive/Colab Notebooks/image-classification-using-svm/dogs-vs-cats/test1.zip")

# %%
test_images_list = sorted(os.listdir("test1"))

print(f"the test dataset has {len(test_images_list)} images")
# Out:
# the test dataset has 12500 images

# %%
test_img = io.imread(os.path.join("test1", test_images_list[100]))

plt.imshow(test_img)
plt.show()

test_img_features = []

gray_test_img = color.rgb2gray(test_img)
edge_test_img = filters.sobel(gray_test_img)
resized_test_img = transform.resize(edge_test_img, (50, 50))
normalized_test_img = resized_test_img / 255.0
flat_test_img = normalized_test_img.flatten()

principal_test_img = pca.transform([flat_test_img])

probability = model.predict_proba(principal_test_img)[0]

print(f'cat = {probability[0]*100}%')
print(f'dog = {probability[1]*100}%')

if model.predict(principal_test_img)[0] == 0:
  print("The predicted image is cat")
else:
  print("The predicted image is dog")
# Out:
# cat = 57.34671555163694%
# dog = 42.653284448363074%
# The predicted image is cat

# %%
test_img = io.imread(os.path.join("test1", test_images_list[500]))

plt.imshow(test_img)
plt.show()

gray_test_img = color.rgb2gray(test_img)
edge_test_img = filters.sobel(gray_test_img)
resized_test_img = transform.resize(edge_test_img, (50, 50))
normalized_test_img = resized_test_img / 255.0
flat_test_img = normalized_test_img.flatten()

principal_test_img = pca.transform([flat_test_img])

probability = model.predict_proba(principal_test_img)[0]

print(f'cat = {probability[0]*100}%')
print(f'dog = {probability[1]*100}%')

if model.predict(principal_test_img)[0] == 0:
  print("The predicted image is cat")
else:
  print("The predicted image is dog")
# Out:
# cat = 7.6592740586361465%
# dog = 92.34072594136387%
# The predicted image is dog
